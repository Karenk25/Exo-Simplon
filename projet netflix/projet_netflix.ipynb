# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Lire un fichier

# %%
#1. Lire le fichier

donnees = pd.read_csv('netflix_titles.csv',index_col ="show_id")
donnees.head()

donnees
# Out:
#              type                                        title  \
# show_id
# 81145628    Movie      Norm of the North: King Sized Adventure
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# ...           ...                                          ...
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# ...

# %% [markdown]
# # Afficher les dimensions du dataframe

# %%
#2. Afficher les dimensions du dataframe

donnees.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Compter les films et séries

# %%
#3. Compter les films et les séries

donnees.type.value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %% [markdown]
# # Générer le résumé statistique du dataframe

# %%
#4. Générer le résumé statistique du dataframe

donnees.describe(include = "all")
# Out:
#          type        title                director                cast  \
# count    6234         6234                    4265                5664
# unique      2         6172                    3301                5469
# top     Movie  Oh My Ghost  Raúl Campos, Jan Suter  David Attenborough
# freq     4265            3                      18                  18
# mean      NaN          NaN                     NaN                 NaN
# std       NaN          NaN                     NaN                 NaN
# min       NaN          NaN                     NaN                 NaN
# 25%       NaN          NaN                     NaN                 NaN
# 50%       NaN          NaN                     NaN                 NaN
# 75%       NaN          NaN                     NaN                 NaN
# max       NaN          NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# ...

# %% [markdown]
# # Compter les valeurs manquantes

# %%
#5. Compter les valeurs manquantes

donnees.isna().sum()
# Out:
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# Unnamed: 12     6233
# dtype: int64

# %% [markdown]
# # Explorer les valeurs manquantes

# %%
#6. Explorer les valeurs manquantes

sous_tableau = donnees.loc[donnees["director"].isna()].type.value_counts()
sous_tableau
# Out:
# TV Show    1841
# Movie       128
# Name: type, dtype: int64

# %% [markdown]
# # 6 bis

# %%
#6(b)

sansActeur = donnees.loc[donnees['cast'].isna()].listed_in.value_counts().head()
sansActeur
# Out:
# Documentaries                          148
# Documentaries, International Movies     94
# Docuseries                              31
# Documentaries, Sports Movies            20
# Crime TV Shows, Docuseries              19
# Name: listed_in, dtype: int64

# %%
#7. Supprimer les lignes dupliquées

donnees.duplicated().sum()
# Out:
# 1

# %%
#donnees.duplicated()

donnees.drop_duplicates(inplace = True)

# %%
#8. Compter les films/séries produits par les États-Unis et par la
#France

donnees[(donnees["country"]=="France") | (donnees["country"]=="United States")].shape[0]
# Out:
# 2122

# %%
#9. Afficher le contenu le plus vieux disponible sur Netflix
donnees[(donnees["release_year"]== donnees["release_year"].min())]
# Out:
#              type                              title director cast country  \
# show_id
# 81030762  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN     NaN
#
#                  date_added  release_year rating  duration listed_in  \
# show_id
# 81030762  December 30, 2018          1925  TV-PG  1 Season  TV Shows
#
#                                                 description Unnamed: 12
# show_id
# 81030762  This collection restores films from women who ...         NaN

# %%
#10. Afficher le film avec la durée la plus longue sur Netflix
duree = donnees[(donnees["type"]=="Movie")]["duration"]
duree = duree.str.replace("min","")
duree = duree.astype("int")
duree = duree.sort_values(ascending = False)
donnees.reindex(index = duree.index ).head(5)
# Out:
#            type                       title            director  \
# show_id
# 80988062  Movie  Black Mirror: Bandersnatch                 NaN
# 60002818  Movie                      Sangam          Raj Kapoor
# 60020906  Movie                      Lagaan  Ashutosh Gowariker
# 70090035  Movie                Jodhaa Akbar  Ashutosh Gowariker
# 80175798  Movie                The Irishman     Martin Scorsese
#
#                                                        cast        country  \
# show_id
# 80988062  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# 60002818  Raj Kapoor, Vyjayanthimala, Rajendra Kumar, La...          India
# 60020906  Aamir Khan, Gracy Singh, Rachel Shelley, Paul ...          India
# 70090035  Hrithik Roshan, Aishwarya Rai Bachchan, Sonu S...          India
# 80175798  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
#
#                  date_added  release_year rating duration  \
# show_id
# ...

# %%
#11. Étudier les catégories avec le plus de contenu

listed_in = pd.Series(", ".join(donnees["listed_in"].dropna()).split(", "))
listed_in.value_counts().head()
# Out:
# International Movies      1926
# Dramas                    1622
# Comedies                  1113
# International TV Shows    1001
# Documentaries              668
# dtype: int64

# %%
#12 Afficher les directeurs qui ont produit le plus de films/séries disponibles sur Netflix
director = pd.Series(", ".join(donnees["director"].dropna()).split(", "))
director.value_counts().head()
# Out:
# Jan Suter       21
# Raúl Campos     19
# Marcus Raboy    14
# Jay Karas       14
# Jay Chapman     12
# dtype: int64

# %%
#13. Voir si Jan Suter travaille souvent avec les mêmes acteurs

donnees_real = donnees [(donnees["director"].notna())]
donnees_jan_suter = donnees_real[(donnees_real["director"].str.contains("Jan Suter"))]
acteur_jan_suter =pd.Series(", ".join(donnees_jan_suter["cast"].dropna()).split(", "))
acteur_jan_suter.value_counts().head(5)
# Out:
# Sofía Niño de Rivera    3
# Carlos Ballarta         3
# Ricardo O'Farrill       2
# Luciano Mellera         1
# Manu NNa                1
# dtype: int64

# %%
#14. Représenter les dix pays qui ont produit le plus de contenus disponibles sur Netflix, avec le nombre de contenus par
#pays

film = pd.Series(", ".join(donnees["country"].dropna()).split(", "))
film = film.value_counts().head(10)
film10 = donnees[(donnees["country"].isin(film.index))]

plt.figure(figsize = [14,6])
sns.countplot(x = "country", data = film10)
plt.xticks(rotation=90)
plt.show()

# %%
#15. Tracer un graphe à barres du nombre de films/séries par
#classement de contenu (rating)
plt.figure(figsize = [14,8])
sns.countplot(x = "rating", data=donnees,
             order = donnees["rating"].value_counts().keys())

# %% [markdown]
# # Evolution du nombre de film/séries

# %%
#16. Afficher l’évolution du nombre de films/séries disponibles
#sur Netflix au cours du temps

donnees["year_added"]=pd.to_datetime(donnees.date_added).dt.year
group = donnees.groupby(by = ['year_added',"type"]).size().reset_index(name = "count")
plt.figure(figsize=[14,8])
plt.xticks(rotation=90)
sns.pointplot(x= "year_added", y = "count", hue= "type", data =group)

# %% [markdown]
# # Distribution de la durée des films

# %%
#17. Afficher la distribution de la durée des films disponibles
#sur Netflix

dureefilm = donnees[(donnees["type"]=="Movie")]["duration"]
dureefilm = dureefilm.str.replace("min","")
dureefilm = dureefilm.astype("int")

plt.figure(figsize=[14,6])
sns.distplot(dureefilm)

# %% [markdown]
# # Tracer un graphique representant le nombre de series

# %%
#18. Tracer un graphique représentant le nombre de séries par
#modalité de nombre de saisons

contenuetvshow = donnees[(donnees["type"]=="TV Show")]
plt.figure(figsize=[16,8])
sns.countplot(x="duration" ,data=contenuetvshow, order = contenuetvshow['duration'].value_counts().keys())
plt.xticks(rotation=90)
plt.xlabel("Saisons",fontsize=15)
plt.ylabel("Series",fontsize=15)
# Out:
# Text(0, 0.5, 'Series')

# %% [markdown]
# # Pour cette partie chargez à nouveau les données avec pd.read_csv() mais cette fois-ci n’utilisez pas l’option index_col

# %%
donnees = pd.read_csv('//home//simplon//Downloads//netflix_titles (1).csv')
#donnees.drop(donnees.columns[12], axis=1, inplace=True) #rustine
donnees = donnees.drop_duplicates(subset=donnees.columns[1:])
donnees
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %% [markdown]
# # 19. Avec Workbench créez la base Netflix et les tables destiner à accueillir les données structurées

# %% [markdown]
# # 20. Créez un dataframe nommé « show_listed_in » ayant pour seul colonne « show_id » et « listed_in ».

# %%
donneescat= donnees[donnees['listed_in'].notna()][['show_id','listed_in']]
show_listed_in = pd.DataFrame(columns = ['show_id','listed_in'])
for i in donneescat.index:
    liste1 = donneescat["listed_in"][i].split(", ")
    liste2 = [donneescat["show_id"][i]] * len(liste1) 
    df = pd.DataFrame({'show_id': liste2, 'listed_in': liste1}, columns = ['show_id', 'listed_in'])
    show_listed_in = show_listed_in.append(df, ignore_index = True)
show_listed_in
# Out:
#         show_id                 listed_in
# 0      81145628  Children & Family Movies
# 1      81145628                  Comedies
# 2      80117401           Stand-Up Comedy
# 3      70234439                  Kids' TV
# 4      80058654                  Kids' TV
# ...         ...                       ...
# 13662  70281022          British TV Shows
# 13663  70281022               TV Comedies
# 13664  70281022                 TV Dramas
# 13665  70153404         Classic & Cult TV
# 13666  70153404               TV Comedies
#
# [13667 rows x 2 columns]

# %% [markdown]
# # 21. Créez un dataframe nommé « listed_in » ayant pour colonne « listed_in_id » et « listed_in ».

# %%
listed_in = show_listed_in["listed_in"].drop_duplicates()
listed_in = listed_in.reset_index(drop=True)
listed_in = listed_in.reset_index()
listed_in = listed_in.rename(columns={"index":"listed_in_id","listed_in":"listed_in"})
show_listed_in = show_listed_in.merge(listed_in).drop("listed_in", axis = 1)
show_listed_in
# Out:
#         show_id  listed_in_id
# 0      81145628             0
# 1      80182480             0
# 2      80182483             0
# 3      80182596             0
# 4      80182482             0
# ...         ...           ...
# 13662  80023876            41
# 13663  70142437            41
# 13664  70140450            41
# 13665  70153412            41
# 13666  70153404            41
#
# [13667 rows x 2 columns]

# %%
listed_in
# Out:
#     listed_in_id                     listed_in
# 0              0      Children & Family Movies
# 1              1                      Comedies
# 2              2               Stand-Up Comedy
# 3              3                      Kids' TV
# 4              4                Crime TV Shows
# 5              5        International TV Shows
# 6              6     Spanish-Language TV Shows
# 7              7          International Movies
# 8              8              Sci-Fi & Fantasy
# 9              9                     Thrillers
# 10            10                    Docuseries
# 11            11           Science & Nature TV
# 12            12            Action & Adventure
# 13            13                        Dramas
# 14            14                   Cult Movies
# 15            15            Independent Movies
# 16            16               Romantic Movies
# 17            17                 Documentaries
# 18            18                 Horror Movies
# ...

# %% [markdown]
# # 22. Faire de même avec les colonnes director et cast en créant des dataframe qui leur sont dédier.

# %%
donneesdir = donnees[donnees['director'].notna()][['show_id','director']]
show_director = pd.DataFrame(columns = ['show_id','director'])
for i in donneesdir.index:
    liste1 = donneesdir["director"][i].split(", ")
    liste2 = [donneesdir["show_id"][i]] * len(liste1) 
    df = pd.DataFrame({'show_id': liste2, 'director': liste1}, columns = ['show_id', 'director'])
    show_director = show_director.append(df)
show_director  
director_id = show_director["director"].drop_duplicates()
director_id = director_id.reset_index(drop=True)
director_id = director_id.reset_index()
director_id = director_id.rename(columns={"index":"director_id","director":"director"})
show_director.merge(director_id).drop("director", axis = 1)
# Out:
#        show_id  director_id
# 0     81145628            0
# 1     81145628            1
# 2     81065331            1
# 3     80125979            2
# 4     70304989            3
# ...        ...          ...
# 4846  80176929         3651
# 4847  80176842         3651
# 4848  80176929         3652
# 4849  80063224         3653
# 4850  80126599         3654
#
# [4851 rows x 2 columns]

# %%
director_id
# Out:
#       director_id          director
# 0               0      Richard Finn
# 1               1        Tim Maltby
# 2               2  Fernando Lebrija
# 3               3       Gabe Ibáñez
# 4               4      Rodrigo Toro
# ...           ...               ...
# 3650         3650       James Hawes
# 3651         3651        Jung-ah Im
# 3652         3652       Seung-uk Jo
# 3653         3653   Andy Devonshire
# 3654         3654         Onur Ünlü
#
# [3655 rows x 2 columns]

# %%
donneescast = donnees[donnees['cast'].notna()][['show_id','cast']]
show_cast = pd.DataFrame(columns = ['show_id','cast'])
for i in donneescast.index:
    liste1 = donneescast["cast"][i].split(", ")
    liste2 = [donneescast["show_id"][i]] * len(liste1) 
    df = pd.DataFrame({'show_id': liste2, 'cast': liste1}, columns = ['show_id', 'cast'])
    show_cast = show_cast.append(df)
show_cast  
cast_id = show_cast["cast"].drop_duplicates()
cast_id = cast_id.reset_index(drop=True)
cast_id = cast_id.reset_index()
cast_id = cast_id.rename(columns={"index":"cast_id","cast":"cast"})
show_cast.merge(cast_id).drop("cast", axis = 1)
# Out:
#         show_id  cast_id
# 0      81145628        0
# 1      81065331        0
# 2      70109891        0
# 3      81145628        1
# 4      80191075        1
# ...         ...      ...
# 44300  70281022    27400
# 44301  70281022    27401
# 44302  70281022    27402
# 44303  70281022    27403
# 44304  70153404    27404
#
# [44305 rows x 2 columns]

# %%
cast_id
# Out:
#        cast_id              cast
# 0            0     Alan Marriott
# 1            1       Andrew Toth
# 2            2      Brian Dobson
# 3            3       Cole Howard
# 4            4  Jennifer Cameron
# ...        ...               ...
# 27400    27400   Rosie Cavaliero
# 27401    27401  Vicki Pepperdine
# 27402    27402   Margaret Clunie
# 27403    27403         Tim Steed
# 27404    27404     Matthew Perry
#
# [27405 rows x 2 columns]

# %%
donneescountry = donnees[donnees['country'].notna()][['show_id','country']]
show_country = pd.DataFrame(columns = ['show_id','country'])
for i in donneescountry.index:
    liste1 = donneescountry["country"][i].split(", ")
    liste2 = [donneescountry["show_id"][i]] * len(liste1) 
    df = pd.DataFrame({'show_id': liste2, 'country': liste1}, columns = ['show_id', 'country'])
    show_country = show_country.append(df)
show_country  
country_id = show_country["country"].drop_duplicates()
country_id = country_id.reset_index(drop=True)
country_id = country_id.reset_index()
country_id = country_id.rename(columns={"index":"country_id","country":"country"})
show_country.merge(country_id).drop("country", axis = 1)
# Out:
#        show_id  country_id
# 0     81145628           0
# 1     70234439           0
# 2     80058654           0
# 3     80125979           0
# 4     70304989           0
# ...        ...         ...
# 7173  70308278         108
# 7174  70308278         109
# 7175  80217848         110
# 7176  80217848         111
# 7177  80162994         112
#
# [7178 rows x 2 columns]

# %%
country_id
# Out:
#      country_id         country
# 0             0   United States
# 1             1           India
# 2             2     South Korea
# 3             3           China
# 4             4  United Kingdom
# ..          ...             ...
# 108         108         Bermuda
# 109         109         Ecuador
# 110         110           Syria
# 111         111          Kuwait
# 112         112          Cyprus
#
# [113 rows x 2 columns]

# %%
show_duration = pd.DataFrame(columns = ['show_id','duration'])

for i in donnees.index:
    liste1 = donnees["duration"][i].split(", ")
    liste2 = [donnees["show_id"][i]] * len(liste1) 
    df = pd.DataFrame({'show_id': liste2, 'duration': liste1}, columns = ['show_id', 'duration'])
    show_duration = show_duration.append(df)
show_duration = show_duration["duration"].drop_duplicates()


show_duration = show_duration.reset_index(drop=True)

show_duration = show_duration.reset_index()

show_duration = show_duration.rename(columns={"index":"duration_id","duration":"duration"})


show_duration.duration = show_duration.duration.str.replace("Seasons","")
show_duration.duration = show_duration.duration.str.replace("Season", "")
show_duration.duration = show_duration.duration.str.replace("min", "")
show_duration.duration = show_duration.duration.astype("int")

show_duration
# Out:
#      duration_id  duration
# 0              0        90
# 1              1        99
# 2              2       110
# 3              3        60
# 4              4        95
# ..           ...       ...
# 179          179         2
# 180          180        14
# 181          181         4
# 182          182         8
# 183          183         6
#
# [184 rows x 2 columns]

# %%
catalogue = donnees.drop(columns=['listed_in','country','director','cast'])
catalogue.date_added =pd.to_datetime(catalogue['date_added'])
catalogue.duration = catalogue.duration.str.replace("Seasons","")
catalogue.duration = catalogue.duration.str.replace("Season", "")
catalogue.duration = catalogue.duration.str.replace("min", "")
catalogue.duration = catalogue.duration.astype("int")
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#      date_added  release_year    rating  duration  \
# 0    2019-09-09          2019     TV-PG        90
# ...

# %% [markdown]
# # 23. Intégrez les dataframes dans la base de données structuré.

# %%
import sqlalchemy 
from sqlalchemy import create_engine

# %%
show_listed_in
# Out:
#      show_id                     listed_in
# 0   81145628      Children & Family Movies
# 1   81145628                      Comedies
# 0   80125979                      Comedies
# 0   70304989          International Movies
# 1   70304989              Sci-Fi & Fantasy
# ..       ...                           ...
# 1   80176842               Korean TV Shows
# 2   80176842  Stand-Up Comedy & Talk Shows
# 0   80126599        International TV Shows
# 1   80126599             Romantic TV Shows
# 2   80126599                   TV Comedies
#
# [8365 rows x 2 columns]

# %%
engine = create_engine('mysql+pymysql://simplon:Simplon123*@localhost:3306/Netflix')

# %%
show_listed_in.to_sql('catalogue_listed', con=engine, index= False, if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...
